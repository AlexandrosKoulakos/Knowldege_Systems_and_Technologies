# %%
# !pip install rdflib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 482 kB 13.0 MB/s
# ...
#      |████████████████████████████████| 41 kB 637 kB/s
# ...

# %%
# Load enhanced_graph.nt
from rdflib import Graph, Literal, URIRef, Namespace

g = Graph()
g.parse('enhanced_graph.nt', format='nt')
# Out:
# <Graph identifier=N08491f531c3141d194504bad2fbaa3ce (<class 'rdflib.graph.Graph'>)>

# %%
# Find all genres

ans=g.query(
    """
      PREFIX exp: <http://example.org/props/>
      PREFIX ex: <http://example.org/ns/>
      
      SELECT DISTINCT ?genre
       WHERE {
          # ?song exp:genre ?genre
       }""")
for a in ans:
  print(a)
# Out:
# (rdflib.term.URIRef('http://example.org/ns/Instrumental'),)
# (rdflib.term.URIRef('http://example.org/ns/Opera'),)
# (rdflib.term.URIRef('http://example.org/ns/Classical'),)
# (rdflib.term.URIRef('http://example.org/ns/Rock'),)
# (rdflib.term.URIRef('http://example.org/ns/Country'),)
# (rdflib.term.URIRef('http://example.org/ns/Pop'),)
# (rdflib.term.URIRef('http://example.org/ns/Traditional_Folk'),)
# (rdflib.term.URIRef('http://example.org/ns/Jazz'),)
# (rdflib.term.URIRef('http://example.org/ns/Funk'),)
# (rdflib.term.URIRef('http://example.org/ns/Reggae'),)
# (rdflib.term.URIRef('http://example.org/ns/Hip_Hop'),)

# %%
# Find all instruments

ans=g.query(
    """
      PREFIX exp: <http://example.org/props/>
      PREFIX ex: <http://example.org/ns/>
      
      SELECT DISTINCT ?instrument
       WHERE {
          # ?song exp:instrument ?instrument
       }""")
for a in ans:
  print(a)
# Out:
# (rdflib.term.URIRef('http://example.org/ns/Bass'),)
# (rdflib.term.URIRef('http://example.org/ns/Drums'),)
# (rdflib.term.URIRef('http://example.org/ns/Woodwind'),)
# (rdflib.term.URIRef('http://example.org/ns/Brass'),)
# (rdflib.term.URIRef('http://example.org/ns/Acoustic_Guitar'),)
# (rdflib.term.URIRef('http://example.org/ns/Orchestra'),)
# (rdflib.term.URIRef('http://example.org/ns/Piano'),)
# (rdflib.term.URIRef('http://example.org/ns/Electric_Guitar'),)
# (rdflib.term.URIRef('http://example.org/ns/Synthesizer'),)
# (rdflib.term.URIRef('http://example.org/ns/Violin'),)
# (rdflib.term.URIRef('http://example.org/ns/Harmonica'),)
# (rdflib.term.URIRef('http://example.org/ns/Banjo'),)

# %%
# Find all emotions

ans=g.query(
    """
      PREFIX exp: <http://example.org/props/>
      PREFIX ex: <http://example.org/ns/>
      
      SELECT DISTINCT ?emotion
       WHERE {
          # ?song exp:emotion ?emotion
       }""")
for a in ans:
  print(a)
# Out:
# (rdflib.term.URIRef('http://example.org/ns/Pleasure'),)
# (rdflib.term.URIRef('http://example.org/ns/Joy'),)
# (rdflib.term.URIRef('http://example.org/ns/Calmness'),)
# (rdflib.term.URIRef('http://example.org/ns/Sadness'),)
# (rdflib.term.URIRef('http://example.org/ns/Anxiety'),)
# (rdflib.term.URIRef('http://example.org/ns/Boredom'),)
# (rdflib.term.URIRef('http://example.org/ns/Arousal'),)
# (rdflib.term.URIRef('http://example.org/ns/Fear'),)

# %%
# Find all languages

ans=g.query(
    """
      PREFIX exp: <http://example.org/props/>
      PREFIX ex: <http://example.org/ns/>
      
      SELECT DISTINCT ?genre
       WHERE {
          # ?song exp:language ?genre
       }""")
for a in ans:
  print(a)
# Out:
# (rdflib.term.Literal('English', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('Italian', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('German', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('Austrian German', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('Portuguese', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('Spanish', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('French', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('British English', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# (rdflib.term.Literal('Dutch', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),)
# ...

# %%
# Find all genres

ans=g.query(
    """
      PREFIX exp: <http://example.org/props/>
      PREFIX ex: <http://example.org/ns/>
      
      SELECT DISTINCT ?song
       WHERE {
          # ?song exp:language 'English'^^<http://www.w3.org/2001/XMLSchema#string>
       }""")

print(len(ans))
for a in ans:
  print(a)
# Out:
# 48
# (rdflib.term.URIRef('http://example.org/ns/More_Than_This'),)
# (rdflib.term.URIRef('http://example.org/ns/The_Collection'),)
# (rdflib.term.URIRef('http://example.org/ns/Let_s_Dance'),)
# (rdflib.term.URIRef('http://example.org/ns/Hell_s_Bells'),)
# (rdflib.term.URIRef('http://example.org/ns/Porgy_and_Bess'),)
# (rdflib.term.URIRef('http://example.org/ns/Tina'),)
# (rdflib.term.URIRef('http://example.org/ns/I_m_Ready'),)
# (rdflib.term.URIRef('http://example.org/ns/Fearless'),)
# (rdflib.term.URIRef('http://example.org/ns/Youngblood'),)
# (rdflib.term.URIRef('http://example.org/ns/Dirty_Deeds_Done_Dirt_Cheap'),)
# (rdflib.term.URIRef('http://example.org/ns/Portrait'),)
# (rdflib.term.URIRef('http://example.org/ns/Be_Here_Now'),)
# (rdflib.term.URIRef('http://example.org/ns/Sweet_Caroline'),)
# (rdflib.term.URIRef('http://example.org/ns/Creep'),)
# (rdflib.term.URIRef('http://example.org/ns/The_Saint'),)
# (rdflib.term.URIRef('http://example.org/ns/Requiem'),)
# ...
